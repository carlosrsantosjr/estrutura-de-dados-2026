# %% [markdown]
# # Introdução as Estruturas de Dados + TADs

# %% [markdown]
# ---
# **Estrutura de Dados**
#
# Tecnologia em Análise e Desenvolvimento de Sistemas
#
# Instituto Federal de Mato Grosso do Sul - Câmpus Três Lagoas
#
# Prof. Carlos R Santos Jr
#
# 1° Semestre de 2026
#
# ---

# %% [markdown]
# **Objetivo**
#
# - Entender o que é uma estrutura de dados
# - Introduzir TAD
# - Trabalhar com listas em Python

# %% [markdown]
# **Conceito**
#
# Estrutura de dados = forma de organizar dados
#
# Exemplos:
# - Lista
# - Pilha
# - Fila

# %%
# ------------------------------------------------------------
# Exemplo com lista
# ------------------------------------------------------------

alunos = ["Ana", "Carlos", "João"]

# Inserção
alunos.append("Maria")

# Remoção
alunos.remove("João")

# Acesso
print(alunos[0])
# Out:
# Ana

# %% [markdown]
# **Operações**
#
# Operações básicas:
# - inserir
# - remover
# - buscar
# - percorrer
