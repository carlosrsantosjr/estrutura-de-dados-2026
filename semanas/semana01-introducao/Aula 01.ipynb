# %%
# ------------------------------------------------------------
# Exemplo com lista
# ------------------------------------------------------------

alunos = ["Ana", "Carlos", "João"]

# Inserção
alunos.append("Maria")

# Remoção
alunos.remove("João")

# Acesso
print(alunos[0])

# ------------------------------------------------------------
# ⚙️ Operações
# ------------------------------------------------------------
"""
Operações básicas:
- inserir
- remover
- buscar
- percorrer
"""

# ------------------------------------------------------------
# 🧪 Exercício em sala
# ------------------------------------------------------------

# Adicione 3 elementos e remova 1
lista = []

# TODO: implementar
